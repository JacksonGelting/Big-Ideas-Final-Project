# %%
#import pandas as pd

#housingData = pd.read_csv('housing.csv')
#housingData.drop(['Sector #','Population (2010)','Total # Units (2000)','# Occupied Units (2010)','% Owner Occupied Units (2010)','% Renter Occupied Units (2010)','Est. Avg. Yrs. of Residence (2010)','% Living in Household (2010)','% Living in Group Quarters (2010)','% Units Built 00-09','% Units Built 90-99','% Units Built 80-89','% Units Built 60-79','% Units Built 40-59','% Units Built before 1939','Median Home Value (2000)','Median Home  Value (2010)','% Change Real Value 2000-2010','Median Sale Price (2010)','# Sales Counted (2010)','Foreclosures (2008)','Foreclosures (2010)','% of all Housing Units Foreclosed (2010)'],axis=1,inplace=True)
#clearedData = housingData.sort_values(by=['% Occupied Units (2010)'], ascending = [False]).reset_index(drop=True)
#clearedData.assign(Housing_Rank = 1)
#clearedData['Housing_Rank'] = clearedData['% Occupied Units (2010)'].rank(ascending = False)

#def remove_percentage(x):
 #   return x.strip('%')

#clearedData['% Occupied Units (2010)'] = clearedData['% Occupied Units (2010)'].apply(remove_percentage).astype('float')

#topFifteen = clearedData.head(15)

#units = topFifteen.set_index("Neighborhood")
#units.plot(kind='bar', y= '% Occupied Units (2010)', ylim = [94, 97])
#units.describe()
# Out:
#        % Occupied Units (2010)  Housing_Rank
# count                10.000000     10.000000
# mean                 95.150000      5.550000
# std                   0.631137      3.104209
# min                  94.300000      1.000000
# 25%                  94.650000      3.500000
# 50%                  95.150000      5.500000
# 75%                  95.400000      7.750000
# max                  96.300000     10.500000

# %%
# first lets import Pandas!
import pandas as pd

# %%
# great! Now let's work.
# We have to import the CSV file that contains all of the information about housing. I set this as 'housingData'

housingData = pd.read_csv('housing.csv')

# let's see what the default data set looks like

housingData
# Out:
#            Neighborhood  Sector # Population (2010) Total # Units (2000)  \
# 0      Allegheny Center         3               933                  675
# 1        Allegheny West         3               462                  390
# 2             Allentown         6             2,500                1,505
# 3             Arlington         7             1,869                  880
# 4     Arlington Heights         7               244                  557
# ..                  ...       ...               ...                  ...
# 85  Upper Lawrenceville        13             2,669                1,504
# 86             West End         4               254                  211
# 87         West Oakland        14             2,604                  638
# 88             Westwood         4             3,066                1,499
# 89              Windgap         4             1,369                  667
#
#    Total # Units (2010) % Occupied Units (2010) % Vacant Units (2010)  \
# 0                 1,052                   51.5%                 48.5%
# 1                   355                   74.9%                 25.1%
# 2                 1,291                   80.0%                 20.0%
# 3                   886                   86.6%                 13.4%
# 4                   148                   91.2%                  8.8%
# ..                  ...                     ...                   ...
# 85                1,442                   81.0%                 19.0%
# 86                  165                   74.5%                 25.5%
# 87                  687                   86.5%                 13.5%
# 88                1,496                   93.8%                  6.2%
# 89                  671                   93.6%                  6.4%
#
#    # Occupied Units (2010) % Owner Occupied Units (2010)  \
# 0                      535                         10.1%
# 1                      203                         18.2%
# 2                      953                         59.2%
# 3                      754                         65.4%
# 4                      139                         18.7%
# ..                     ...                           ...
# 85                   1,183                         60.6%
# 86                      62                         33.9%
# 87                     580                         38.4%
# 88                   1,470                         78.2%
# 89                     615                         91.1%
#
#    % Renter Occupied Units (2010)  ...  % Units Built before 1939  \
# 0                           89.9%  ...                       1.3%
# 1                           81.8%  ...                      57.4%
# 2                           40.8%  ...                      62.9%
# 3                           34.6%  ...                      72.3%
# 4                           81.3%  ...                       9.2%
# ..                            ...  ...                        ...
# 85                          39.4%  ...                      79.6%
# 86                          66.1%  ...                      73.3%
# 87                          61.6%  ...                      47.1%
# 88                          21.8%  ...                      24.2%
# 89                           8.9%  ...                      32.1%
#
#    Median Home Value (2000) Med. Val. ('00 in '10 Dollars)  \
# 0                   $86,500                       $109,535
# 1                  $159,700                       $202,228
# 2                   $34,300                        $43,434
# 3                   $38,800                        $49,132
# 4                   $45,000                        $56,984
# ..                      ...                            ...
# 85                  $35,900                        $45,460
# 86                  $26,800                        $33,937
# 87                  $47,500                        $60,149
# 88                  $72,200                        $91,427
# 89                  $66,000                        $83,576
#
#    Median Home  Value (2010) % Change Real Value 2000-2010  \
# 0                   $136,300                         24.4%
# 1                   $123,600                        -38.9%
# 2                    $42,200                         -2.8%
# 3                    $44,200                        -10.0%
# 4                    $64,400                         13.0%
# ..                       ...                           ...
# 85                   $48,700                          7.1%
# 86                   $29,800                        -12.2%
# 87                   $61,100                          1.6%
# 88                   $93,700                          2.5%
# 89                   $78,200                         -6.4%
#
#    Median Sale Price (2010) # Sales Counted (2010) Foreclosures (2008)  \
# 0                       NaN                      0                   0
# 1                  $309,940                      7                   0
# 2                    $8,500                     70                  27
# 3                   $15,397                     34                  12
# 4                       NaN                      0                   0
# ..                      ...                    ...                 ...
# 85                  $38,000                     65                  14
# 86                  $14,383                     10                   2
# 87                  $66,000                     17                   3
# 88                  $70,000                     49                  11
# 89                  $59,950                     22                   4
#
#    Foreclosures (2010) % of all Housing Units Foreclosed (2010)
# 0                    0                                     0.0%
# 1                    1                                     0.3%
# 2                   11                                     0.9%
# 3                   13                                     1.5%
# 4                    0                                     0.0%
# ..                 ...                                      ...
# 85                   7                                     0.5%
# 86                   8                                     4.8%
# 87                   1                                     0.1%
# 88                   2                                     0.1%
# 89                  13                                     1.9%
#
# [90 rows x 28 columns]

# %%
# woah! that's a lot of data. Lot's of columns and rows. A lot of these we don't want to deal with.
housingData.drop(['Sector #','Population (2010)','Total # Units (2000)','# Occupied Units (2010)','% Owner Occupied Units (2010)','% Renter Occupied Units (2010)','Est. Avg. Yrs. of Residence (2010)','% Living in Household (2010)','% Living in Group Quarters (2010)','% Units Built 00-09','% Units Built 90-99','% Units Built 80-89','% Units Built 60-79','% Units Built 40-59','% Units Built before 1939','Median Home Value (2000)','Median Home  Value (2010)','% Change Real Value 2000-2010','Median Sale Price (2010)','# Sales Counted (2010)','Foreclosures (2008)','Foreclosures (2010)','% of all Housing Units Foreclosed (2010)'],axis=1,inplace=True)

# NOW let's see what that looks like after dropping most of the columns
housingData
# Out:
#            Neighborhood Total # Units (2010) % Occupied Units (2010)  \
# 0      Allegheny Center                1,052                   51.5%
# 1        Allegheny West                  355                   74.9%
# 2             Allentown                1,291                   80.0%
# 3             Arlington                  886                   86.6%
# 4     Arlington Heights                  148                   91.2%
# ..                  ...                  ...                     ...
# 85  Upper Lawrenceville                1,442                   81.0%
# 86             West End                  165                   74.5%
# 87         West Oakland                  687                   86.5%
# 88             Westwood                1,496                   93.8%
# 89              Windgap                  671                   93.6%
#
#    % Vacant Units (2010) Med. Val. ('00 in '10 Dollars)
# 0                  48.5%                       $109,535
# 1                  25.1%                       $202,228
# 2                  20.0%                        $43,434
# 3                  13.4%                        $49,132
# 4                   8.8%                        $56,984
# ..                   ...                            ...
# 85                 19.0%                        $45,460
# 86                 25.5%                        $33,937
# 87                 13.5%                        $60,149
# 88                  6.2%                        $91,427
# 89                  6.4%                        $83,576
#
# [90 rows x 5 columns]

# %%
# next, we have to sort the values by the percentage of homes occupied in the neighborhood.

clearedData = housingData.sort_values(by=['% Occupied Units (2010)'], ascending = [False]).reset_index(drop=True)

# let's see what that looks like

clearedData
# Out:
#          Neighborhood Total # Units (2010) % Occupied Units (2010)  \
# 0      Swisshelm Park                  625                   96.3%
# 1           Ridgemont                  218                   95.9%
# 2             Oakwood                  571                   95.4%
# 3          Banksville                2,118                   95.4%
# 4       Regent Square                  479                   95.2%
# ..                ...                  ...                     ...
# 85        South Shore                   15                   66.7%
# 86  Northview Heights                  723                   63.6%
# 87   Allegheny Center                1,052                   51.5%
# 88          St. Clair                  165                   50.3%
# 89            Chateau                    4                  100.0%
#
#    % Vacant Units (2010) Med. Val. ('00 in '10 Dollars)
# 0                   3.7%                       $103,837
# 1                   4.1%                        $89,021
# 2                   4.6%                        $94,339
# 3                   4.6%                       $110,421
# 4                   4.8%                       $143,092
# ..                   ...                            ...
# 85                 33.3%                            NaN
# 86                 36.4%                        $37,229
# 87                 48.5%                       $109,535
# 88                 49.7%                        $56,984
# 89                  0.0%                            NaN
#
# [90 rows x 5 columns]

# %%
# what's that all the way at place 89? Chateau? They have an occupied units of 100% but they only have 4 people. So let's drop them

# clearedData = clearedData.drop(index=89, axis=0)

# now let's see what the data looks like

clearedData
# Out:
#          Neighborhood Total # Units (2010) % Occupied Units (2010)  \
# 0      Swisshelm Park                  625                   96.3%
# 1           Ridgemont                  218                   95.9%
# 2             Oakwood                  571                   95.4%
# 3          Banksville                2,118                   95.4%
# 4       Regent Square                  479                   95.2%
# ..                ...                  ...                     ...
# 84     Homewood South                1,507                   71.6%
# 85        South Shore                   15                   66.7%
# 86  Northview Heights                  723                   63.6%
# 87   Allegheny Center                1,052                   51.5%
# 88          St. Clair                  165                   50.3%
#
#    % Vacant Units (2010) Med. Val. ('00 in '10 Dollars)
# 0                   3.7%                       $103,837
# 1                   4.1%                        $89,021
# 2                   4.6%                        $94,339
# 3                   4.6%                       $110,421
# 4                   4.8%                       $143,092
# ..                   ...                            ...
# 84                 28.4%                        $42,801
# 85                 33.3%                            NaN
# 86                 36.4%                        $37,229
# 87                 48.5%                       $109,535
# 88                 49.7%                        $56,984
#
# [89 rows x 5 columns]

# %%
# The final step is to assign a ranking to all of our neighborhoods.

clearedData.assign(Housing_Rank = 1)
clearedData['Housing_Rank'] = clearedData['% Occupied Units (2010)'].rank(ascending = False)

# let's see what that looks like

clearedData
# Out:
#          Neighborhood Total # Units (2010) % Occupied Units (2010)  \
# 0      Swisshelm Park                  625                   96.3%
# 1           Ridgemont                  218                   95.9%
# 2             Oakwood                  571                   95.4%
# 3          Banksville                2,118                   95.4%
# 4       Regent Square                  479                   95.2%
# ..                ...                  ...                     ...
# 84     Homewood South                1,507                   71.6%
# 85        South Shore                   15                   66.7%
# 86  Northview Heights                  723                   63.6%
# 87   Allegheny Center                1,052                   51.5%
# 88          St. Clair                  165                   50.3%
#
#    % Vacant Units (2010) Med. Val. ('00 in '10 Dollars)  Housing_Rank
# 0                   3.7%                       $103,837           1.0
# 1                   4.1%                        $89,021           2.0
# 2                   4.6%                        $94,339           3.5
# 3                   4.6%                       $110,421           3.5
# 4                   4.8%                       $143,092           5.0
# ..                   ...                            ...           ...
# 84                 28.4%                        $42,801          84.5
# 85                 33.3%                            NaN          86.0
# 86                 36.4%                        $37,229          87.0
# 87                 48.5%                       $109,535          88.0
# 88                 49.7%                        $56,984          89.0
#
# [89 rows x 6 columns]

# %%
# as we can see, Swisshelm Park is rank 1.0, Ridgemont, 2.0, etc. This will be used later for our final metric.

# We want to visualize this data, but in order to do that, we have to chnage our percentages to a float.

def remove_percentage(x):
    return x.strip('%')

clearedData['% Occupied Units (2010)'] = clearedData['% Occupied Units (2010)'].apply(remove_percentage).astype('float')

# this strips the string of the percent sign and makes it a float for us to work with.

# now let's see what our finalists look like. 

topFifteen = clearedData.head(15)

topFifteen
# Out:
#            Neighborhood Total # Units (2010)  % Occupied Units (2010)  \
# 0        Swisshelm Park                  625                     96.3
# 1             Ridgemont                  218                     95.9
# 2               Oakwood                  571                     95.4
# 3            Banksville                2,118                     95.4
# 4         Regent Square                  479                     95.2
# 5          Point Breeze                2,483                     95.1
# 6            Glen Hazel                  249                     94.8
# 7   Squirrel Hill South                7,514                     94.6
# 8         North Oakland                3,761                     94.5
# 9           Summer Hill                  510                     94.3
# 10      Stanton Heights                2,223                     94.3
# 11      Central Oakland                2,531                     94.2
# 12              Bon Air                  387                     94.1
# 13        New Homestead                  429                     93.9
# 14             Westwood                1,496                     93.8
#
#    % Vacant Units (2010) Med. Val. ('00 in '10 Dollars)  Housing_Rank
# 0                   3.7%                       $103,837           1.0
# 1                   4.1%                        $89,021           2.0
# 2                   4.6%                        $94,339           3.5
# 3                   4.6%                       $110,421           3.5
# 4                   4.8%                       $143,092           5.0
# 5                   4.9%                       $207,673           6.0
# 6                   5.2%                            NaN           7.0
# 7                   5.4%                       $170,486           8.0
# 8                   5.5%                       $281,654           9.0
# 9                   5.7%                        $96,365          10.5
# 10                  5.7%                        $84,526          10.5
# 11                  5.8%                        $78,637          12.0
# 12                  5.9%                        $80,157          13.0
# 13                  6.1%                       $115,107          14.0
# 14                  6.2%                        $91,427          15.0

# %%
# finally, let's look at what this data looks like visually

units = topFifteen.set_index("Neighborhood")
units.plot(kind='bar', y= '% Occupied Units (2010)', ylim = [93, 97])

units.describe()
# Out:
#        % Occupied Units (2010)  Housing_Rank
# count                15.000000     15.000000
# mean                 94.786667      8.000000
# std                   0.742454      4.464143
# min                  93.800000      1.000000
# 25%                  94.250000      4.250000
# 50%                  94.600000      8.000000
# 75%                  95.300000     11.250000
# max                  96.300000     15.000000

# %%
# Our first place is winner is Swisshelm Park! But, we have to see how it holds up against our other metrics.
